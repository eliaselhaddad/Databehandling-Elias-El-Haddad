# %% [markdown]
# ## Find missing values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("https://github.com/kokchun/Databehandling-AI22/blob/main/Data/student-mat-missing-data.csv?raw=true") # raw=true is needed to get the raw data
df
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 0             0     GP   F  18.0       U     GT3       A     4     4
# 1             1     GP   F  17.0       U     GT3       T     1     1
# 2             2     GP   F  15.0       U     LE3       T     1     1
# 3             3     GP   F  15.0       U     GT3       T     4     2
# 4             4     GP   F  16.0       U     GT3       T     3     3
# ..          ...    ...  ..   ...     ...     ...     ...   ...   ...
# 390         390     MS   M  20.0       U     LE3       A     2     2
# 391         391     MS   M  17.0       U     LE3       T     3     1
# 392         392     MS   M  21.0       R     GT3       T     1     1
# 393         393     MS   M  18.0       R     LE3       T     3     2
# 394         394     MS   M  19.0       U     LE3       T     1     1
#
#          Mjob  ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  395 non-null    int64
#  1   school      395 non-null    object
#  2   sex         395 non-null    object
#  3   age         381 non-null    float64
#  4   address     390 non-null    object
#  5   famsize     395 non-null    object
#  6   Pstatus     395 non-null    object
#  7   Medu        395 non-null    int64
#  8   Fedu        395 non-null    int64
#  9   Mjob        395 non-null    object
#  10  Fjob        395 non-null    object
#  11  reason      395 non-null    object
#  12  guardian    395 non-null    object
#  13  traveltime  395 non-null    int64
#  14  studytime   395 non-null    int64
#  15  failures    395 non-null    int64
#  16  schoolsup   395 non-null    object
#  17  famsup      395 non-null    object
#  18  paid        395 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         age        Medu        Fedu  traveltime   studytime  \
# count  395.000000  381.000000  395.000000  395.000000  395.000000  395.000000
# mean   197.000000   16.700787    2.749367    2.521519    1.448101    2.035443
# std    114.170924    1.275157    1.094735    1.088201    0.697505    0.839240
# min      0.000000   15.000000    0.000000    0.000000    1.000000    1.000000
# 25%     98.500000   16.000000    2.000000    2.000000    1.000000    1.000000
# 50%    197.000000   17.000000    3.000000    2.000000    1.000000    2.000000
# 75%    295.500000   18.000000    4.000000    3.000000    2.000000    2.000000
# max    394.000000   22.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime       goout        Dalc        Walc  \
# count  395.000000  390.000000  379.000000  390.000000  395.000000  395.000000
# mean     0.334177    3.943590    3.237467    3.120513    1.481013    2.291139
# ...

# %%
df["sex"].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
df["age"].unique()
# Out:
# array([18., 17., 15., 16., nan, 19., 22., 20., 21.])

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# school         0
# sex            0
# age           14
# address        5
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob           0
# Fjob           0
# reason         0
# guardian       0
# traveltime     0
# studytime      0
# failures       0
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         5
# freetime      16
# goout          5
# Dalc           0
# Walc           0
# health         5
# absences       5
# G1             0
# G2             0
# G3             0
# dtype: int64

# %%
from data_utils import plot_missing_values

plot_missing_values(df)

# %%
missing_values = df.isnull().sum().sort_values(ascending=True)
missing_values = missing_values[missing_values > 0]
missing_values
# Out:
# address      5
# goout        5
# health       5
# absences     5
# famrel       5
# age         14
# freetime    16
# dtype: int64

# %%
freetime_nan = df[df["freetime"].isnull()].index.tolist()
print(f"These row indices: {freetime_nan}")
# Out:
# These row indices: [87, 99, 130, 149, 151, 160, 191, 257, 276, 293, 308, 330, 343, 359, 372, 385]

# %%
freetime_age_nan = df[df["freetime"].isnull() | df["age"].isnull()].index.tolist()
print(f"These row indices: {freetime_age_nan}")
# Out:
# These row indices: [20, 71, 87, 99, 102, 106, 121, 130, 149, 151, 160, 188, 191, 214, 257, 270, 276, 293, 308, 330, 343, 348, 359, 372, 385]

# %%
number_of_rows = df.shape[0]
number_of_columns = df.shape[1]
print(f"Number of rows: {number_of_rows}")
print(f"Number of columns: {number_of_columns}")
rows_missing_multiple_values = df.loc[df.isnull().sum(axis=1) > 1].shape[0] 
print(f"Number of rows with multiple missing values: {rows_missing_multiple_values}")
proportion = rows_missing_multiple_values / number_of_rows
print(f"These rows consitute {proportion:.4f} of the dataset")
# Out:
# Number of rows: 395
# Number of columns: 34
# Number of rows with multiple missing values: 5
# These rows consitute 0.0127 of the dataset
# float

# %% [markdown]
# ## Clean the data
